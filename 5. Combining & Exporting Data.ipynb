# %% [markdown]
# ### Combining & Exporting Data. Task 4.6

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #### 1. Importing the orders_products_combined dataframe from the pickle file

# %%
# Impotring df_ords_prods_combined
df_ords_prods_combined = pd.read_pickle(r'C:\Users\ahamr\Desktop\12-2023 Instacart Basket Analysis\02 Data\Prepared Data\orders_products_combined.pkl')

# %% [markdown]
# #### 2. Check the shape of the imported dataframe

# %%
df_ords_prods_combined.shape
# Out:
# (32434489, 11)

# %% [markdown]
# #### 3. Importing the second dataframe

# %%
# Impotring df_prods
df_prods= pd.read_csv(r'C:\Users\ahamr\Desktop\12-2023 Instacart Basket Analysis\02 Data\Prepared Data\products_checked.csv', index_col = False)

# %%
df_prods.shape
# Out:
# (49672, 6)

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_prods_copy = df_prods.drop(columns = ['Unnamed: 0'])

# %%
df_prods_copy
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49667       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49668       49685                 En Croute Roast Hazelnut Cranberry
# 49669       49686                                   Artisan Baguette
# 49670       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49671       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
df_prods = df_prods_copy

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df_ords_prods_combined.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  order_hour  \
# 0   2539329        1    prior             1                   2           8
# 1   2539329        1    prior             1                   2           8
# 2   2539329        1    prior             1                   2           8
# 3   2539329        1    prior             1                   2           8
# 4   2539329        1    prior             1                   2           8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
df_ords_prods_combined_copy = df_ords_prods_combined.drop(columns = ['_merge'])

# %%
df_ords_prods_combined = df_ords_prods_combined_copy

# %% [markdown]
# #### 4. Merging the dataframes

# %%
# Merging the df_prods and df_ords_prods_combined with a merge() function, using the default option of inner join 
df_ords_prods_merge = df_prods.merge(df_ords_prods_combined, on = 'product_id', indicator = True)

# %%
# Checking the output
df_ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  orders_day_of_week  order_hour  \
# 0   3139998      138    prior            28                   6          11
# 1   1977647      138    prior            30                   6          17
# 2    389851      709    prior             2                   0          21
# 3    652770      764    prior             1                   3          13
# 4   1813452      764    prior             3                   4          17
#
# ...

# %%
# Looking at the merge flag frequency
df_ords_prods_merge['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# #### 5. Exporting the file

# %%
# Exporting the df_ords_prods_merge

path = r"C:\Users\ahamr\Desktop\12-2023 Instacart Basket Analysis"
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge.pkl'))
