# %% [markdown]
# ## Combining & Exporting Data

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Importing a df_ords_prior
df_ords_prior = pd.read_csv(r'C:\Users\ahamr\Desktop\12-2023 Instacart Basket Analysis\02 Data\Original Data\orders_products_prior.csv', index_col = False)

# %%
# Check the output
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df_ords = pd.read_csv(r'C:\Users\ahamr\Desktop\12-2023 Instacart Basket Analysis\02 Data\Prepared Data\orders_checked.csv', index_col = False)

# %%
df_ords
# Out:
#          Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                   0           0   2539329        1    prior             1
# 1                   1           1   2398795        1    prior             2
# 2                   2           2    473747        1    prior             3
# 3                   3           3   2254736        1    prior             4
# 4                   4           4    431534        1    prior             5
# ...               ...         ...       ...      ...      ...           ...
# 3421078       3421078     3421078   2266710   206209    prior            10
# 3421079       3421079     3421079   1854736   206209    prior            11
# 3421080       3421080     3421080    626363   206209    prior            12
# 3421081       3421081     3421081   2977660   206209    prior            13
# 3421082       3421082     3421082    272231   206209    train            14
#
# ...

# %%
df_ords_copy = df_ords.drop(columns = ['Unnamed: 0', 'Unnamed: 0.1'])

# %%
df_ords_copy
# Out:
#          order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0         2539329        1    prior             1                   2
# 1         2398795        1    prior             2                   3
# 2          473747        1    prior             3                   3
# 3         2254736        1    prior             4                   4
# 4          431534        1    prior             5                   4
# ...           ...      ...      ...           ...                 ...
# 3421078   2266710   206209    prior            10                   5
# 3421079   1854736   206209    prior            11                   4
# 3421080    626363   206209    prior            12                   1
# 3421081   2977660   206209    prior            13                   1
# 3421082    272231   206209    train            14                   6
#
#          order_hour  days_since_prior_order
# 0                 8                     NaN
# ...

# %%
df_ords = df_ords_copy

# %%
df_ords.shape
# Out:
# (3421083, 7)

# %%
# Merging the two dataftrames
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
df_merged_large.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  order_hour  \
# 0   2539329        1    prior             1                   2           8
# 1   2539329        1    prior             1                   2           8
# 2   2539329        1    prior             1                   2           8
# 3   2539329        1    prior             1                   2           8
# 4   2539329        1    prior             1                   2           8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both          32434489
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
# Export data to pkl

path=r'C:\Users\ahamr\Desktop\12-2023 Instacart Basket Analysis'

df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))
